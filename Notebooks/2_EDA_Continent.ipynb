# %%
import pandas as pd
import numpy as np

# Visualization
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # to be able to display all columns of the DataFrames

# %%
df = pd.read_csv("data/c_continent.csv", index_col=0)

# %%
df.head(5)
# Out:
#                    AVG_Aroma  AVG_Flavor  AVG_Aftertaste  AVG_Acidity  \
# Country.of.Origin
# Africa              7.759444    7.709444        7.623889     7.739074
# Asia                7.539121    7.499286        7.409231     7.478407
# North America       7.504346    7.445714        7.300767     7.496677
# Oceania             8.330000    8.420000        7.830000     8.330000
# South America       7.613415    7.589878        7.491585     7.545915
#
#                    AVG_Body  AVG_Balance  AVG_Uniformity  AVG_Clean.Cup  \
# Country.of.Origin
# Africa             7.680741     7.689938        9.954568       9.979321
# Asia               7.509066     7.473187        9.908187       9.970604
# North America      7.450977     7.432496        9.752632       9.734226
# Oceania            8.000000     8.250000        9.330000       9.330000
# South America      7.574756     7.629177        9.902866       9.894268
#
#                    AVG_Sweetness  AVG_Moisture  AVG_Quakers  \
# Country.of.Origin
# Africa                  9.813148      0.100926     0.166667
# Asia                    9.761813      0.079066     0.115385
# North America           9.852992      0.096857     0.129323
# Oceania                10.000000      0.120000     0.000000
# South America           9.937470      0.070030     0.298780
#
#                    AVG_Category.One.Defects  AVG_Category.Two.Defects  Rec_Cnt
# Country.of.Origin
# Africa                             0.179012                  3.734568      162
# Asia                               0.752747                  1.538462      182
# North America                      0.566917                  4.518797      665
# Oceania                            0.000000                  1.000000        1
# South America                      0.301829                  2.646341      328

# %%
# Cantidad de filas y columnas:
print(f"El número de filas que tenemos es {df.shape[0]}, y el número de columnas es {df.shape[1]}.")
# Out:
# El número de filas que tenemos es 5, y el número de columnas es 14.

# %%
# Function to view the complete Dataframe information.
def get_csv_info(csv):
    # Display the DataFrame info
    print("CSV Information:\n")
    print("-----------------------------------------------------------------------")
    df.info()
    print("-----------------------------------------------------------------------")
    
    # Display the column names
    print("\nColumn Names:")
    print("-----------------------------------------------------------------------")
    print(df.columns)
    print("-----------------------------------------------------------------------")
    
    return 

# Function to view the descriptions of the numerical and categorical columns of the Dataframe.
def describe_dataframe(csv):
    # Describe numerical columns
    print("Numerical Columns Description:\n")
    print("-----------------------------------------------------------------------")
    print(df.describe().T)
    print("-----------------------------------------------------------------------")
    
    return

# %%
get_csv_info(df)
# Out:
# CSV Information:
#
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Africa to South America
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   AVG_Aroma                 5 non-null      float64
#  1   AVG_Flavor                5 non-null      float64
#  2   AVG_Aftertaste            5 non-null      float64
#  3   AVG_Acidity               5 non-null      float64
#  4   AVG_Body                  5 non-null      float64
#  5   AVG_Balance               5 non-null      float64
#  6   AVG_Uniformity            5 non-null      float64
#  7   AVG_Clean.Cup             5 non-null      float64
#  8   AVG_Sweetness             5 non-null      float64
#  9   AVG_Moisture              5 non-null      float64
#  10  AVG_Quakers               5 non-null      float64
#  11  AVG_Category.One.Defects  5 non-null      float64
#  12  AVG_Category.Two.Defects  5 non-null      float64
#  13  Rec_Cnt                   5 non-null      int64
# dtypes: float64(13), int64(1)
# memory usage: 600.0+ bytes
# -----------------------------------------------------------------------
#
# Column Names:
# -----------------------------------------------------------------------
# Index(['AVG_Aroma', 'AVG_Flavor', 'AVG_Aftertaste', 'AVG_Acidity', 'AVG_Body',
#        'AVG_Balance', 'AVG_Uniformity', 'AVG_Clean.Cup', 'AVG_Sweetness',
#        'AVG_Moisture', 'AVG_Quakers', 'AVG_Category.One.Defects',
#        'AVG_Category.Two.Defects', 'Rec_Cnt'],
#       dtype='object')
# -----------------------------------------------------------------------

# %%
describe_dataframe(df)
# Out:
# Numerical Columns Description:
#
# -----------------------------------------------------------------------
#                           count        mean         std       min         25%  \
# AVG_Aroma                   5.0    7.749265    0.339101  7.504346    7.539121
# AVG_Flavor                  5.0    7.732864    0.396914  7.445714    7.499286
# AVG_Aftertaste              5.0    7.531094    0.204584  7.300767    7.409231
# AVG_Acidity                 5.0    7.718014    0.357418  7.478407    7.496677
# AVG_Body                    5.0    7.643108    0.216992  7.450977    7.509066
# AVG_Balance                 5.0    7.694960    0.328060  7.432496    7.473187
# AVG_Uniformity              5.0    9.769650    0.257252  9.330000    9.752632
# AVG_Clean.Cup               5.0    9.781684    0.270969  9.330000    9.734226
# AVG_Sweetness               5.0    9.873085    0.095695  9.761813    9.813148
# AVG_Moisture                5.0    0.093376    0.019543  0.070030    0.079066
# AVG_Quakers                 5.0    0.142031    0.107496  0.000000    0.115385
# AVG_Category.One.Defects    5.0    0.360101    0.301167  0.000000    0.179012
# AVG_Category.Two.Defects    5.0    2.687634    1.467961  1.000000    1.538462
# Rec_Cnt                     5.0  267.600000  250.563964  1.000000  162.000000
#
#                                  50%         75%         max
# AVG_Aroma                   7.613415    7.759444    8.330000
# AVG_Flavor                  7.589878    7.709444    8.420000
# AVG_Aftertaste              7.491585    7.623889    7.830000
# AVG_Acidity                 7.545915    7.739074    8.330000
# AVG_Body                    7.574756    7.680741    8.000000
# AVG_Balance                 7.629177    7.689938    8.250000
# AVG_Uniformity              9.902866    9.908187    9.954568
# AVG_Clean.Cup               9.894268    9.970604    9.979321
# AVG_Sweetness               9.852992    9.937470   10.000000
# AVG_Moisture                0.096857    0.100926    0.120000
# AVG_Quakers                 0.129323    0.166667    0.298780
# AVG_Category.One.Defects    0.301829    0.566917    0.752747
# AVG_Category.Two.Defects    2.646341    3.734568    4.518797
# Rec_Cnt                   182.000000  328.000000  665.000000
# -----------------------------------------------------------------------
