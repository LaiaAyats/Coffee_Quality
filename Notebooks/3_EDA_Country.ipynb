# %%
import pandas as pd
import numpy as np

# Visualization
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # to be able to display all columns of the DataFrames

# %%
df = pd.read_csv("data/c_country.csv", index_col=0)

# %%
df
# Out:
#                    AVG_Aroma  AVG_Flavor  AVG_Aftertaste  AVG_Acidity  \
# Country.of.Origin
# Brazil              7.553106    7.573561        7.440530     7.511439
# Burundi             7.415000    7.460000        7.250000     7.415000
# China               7.641250    7.625625        7.484375     7.578125
# Colombia            7.653060    7.597104        7.524699     7.560000
# Costa Rica          7.671373    7.537255        7.534510     7.573922
# Cote dIvoire        7.420000    7.250000        6.830000     7.000000
# Ecuador             7.583333    7.640000        7.553333     7.693333
# El Salvador         7.674762    7.654286        7.567143     7.590476
# Ethiopia            7.896364    8.009091        7.893864     8.043636
# Guatemala           7.544862    7.489006        7.266851     7.596409
# Haiti               7.153333    6.998333        7.111667     7.126667
# Honduras            7.292453    7.234151        7.061509     7.233585
# India               7.697857    7.618571        7.566429     7.636429
# Indonesia           7.649000    7.573000        7.415500     7.491000
# Japan               7.750000    7.750000        7.750000     7.420000
# Kenya               7.786800    7.782400        7.713200     7.866000
# Laos                7.503333    7.500000        7.280000     7.306667
# Malawi              7.567273    7.387273        7.257273     7.408182
# Mauritius           7.250000    7.250000        7.170000     7.170000
# Mexico              7.457585    7.379025        7.228051     7.428347
# Myanmar             7.303750    7.332500        7.125000     7.406250
# Nicaragua           7.329231    7.316923        7.201923     7.266538
# Panama              7.667500    7.625000        7.605000     7.705000
# Papua New Guinea    8.330000    8.420000        7.830000     8.330000
# Peru                7.693000    7.658000        7.541000     7.699000
# Philippines         7.364000    7.232000        7.302000     7.266000
# Rwanda              7.830000    7.920000        7.750000     7.830000
# Taiwan              7.533600    7.463600        7.395467     7.415467
# Tanzania            7.571250    7.429750        7.425000     7.500000
# Thailand            7.484063    7.528125        7.473438     7.597188
# Uganda              7.884167    7.752778        7.622500     7.708611
# United States       7.605977    7.622529        7.541609     7.651609
# Vietnam             7.386250    7.375000        7.197500     7.362500
# Zambia              7.670000    7.080000        7.420000     7.330000
#
#                    AVG_Body  AVG_Balance  AVG_Uniformity  AVG_Clean.Cup  \
# Country.of.Origin
# Brazil             7.544545     7.531515        9.884924       9.853485
# Burundi            7.290000     7.415000       10.000000      10.000000
# China              7.573750     7.548125        9.958125       9.958125
# Colombia           7.609508     7.708415        9.934426       9.945355
# Costa Rica         7.537451     7.637255        9.856275       9.869216
# Cote dIvoire       7.330000     7.080000        9.330000      10.000000
# Ecuador            6.026667     6.970000       10.000000      10.000000
# El Salvador        7.606667     7.711429        9.936190       9.936190
# Ethiopia           7.924091     7.972273        9.878409       9.954318
# Guatemala          7.475746     7.469890        9.852486       9.889337
# Haiti              7.276667     7.056667        9.776667       8.555000
# Honduras           7.239245     7.163962        9.647736       9.635283
# India              7.661429     7.672857        9.904286       9.952143
# Indonesia          7.631500     7.520000        9.933000       9.966500
# Japan              8.080000     7.830000       10.000000      10.000000
# Kenya              7.726400     7.800400        9.973200       9.973200
# Laos               7.363333     7.416667       10.000000      10.000000
# Malawi             7.338182     7.371818       10.000000      10.000000
# Mauritius          7.250000     7.170000       10.000000      10.000000
# Mexico             7.380466     7.328686        9.744068       9.658136
# Myanmar            7.270000     7.133750       10.000000      10.000000
# Nicaragua          7.400769     7.278462        9.794615       9.769231
# Panama             7.582500     7.875000       10.000000      10.000000
# Papua New Guinea   8.000000     8.250000        9.330000       9.330000
# Peru               7.802000     7.666000        9.533000       9.466000
# Philippines        7.298000     7.400000        9.866000      10.000000
# Rwanda             7.750000     7.750000        9.330000       9.330000
# Taiwan             7.450000     7.426000        9.893067       9.982133
# Tanzania           7.479000     7.469750       10.000000      10.000000
# Thailand           7.552187     7.524063        9.937500       9.958438
# Uganda             7.720000     7.662500       10.000000      10.000000
# United States      7.652414     7.664138        9.501379       9.608966
# Vietnam            7.542500     7.457500        9.666250       9.916250
# Zambia             7.750000     7.420000       10.000000      10.000000
#
#                    AVG_Sweetness  AVG_Moisture  AVG_Quakers  \
# Country.of.Origin
# Brazil                  9.949394      0.082348     0.446970
# Burundi                10.000000      0.060000     0.000000
# China                   9.916250      0.094375     0.500000
# Colombia                9.952678      0.062022     0.207650
# Costa Rica              9.908431      0.083333     0.117647
# Cote dIvoire           10.000000      0.130000     0.000000
# Ecuador                 8.723333      0.030000     0.000000
# El Salvador             9.808571      0.045714     0.095238
# Ethiopia                9.863409      0.082955     0.363636
# Guatemala               9.870884      0.102265     0.276243
# Haiti                   9.111667      0.110000     0.000000
# Honduras                9.660377      0.107736     0.188679
# India                   7.619286      0.037857     0.500000
# Indonesia               9.966500      0.098500     0.050000
# Japan                  10.000000      0.120000     0.000000
# Kenya                   9.973200      0.080000     0.240000
# Laos                   10.000000      0.083333     0.000000
# Malawi                 10.000000      0.124545     0.000000
# Mauritius              10.000000      0.120000     0.000000
# Mexico                  9.971780      0.113602     0.038136
# Myanmar                10.000000      0.013750     0.000000
# Nicaragua               9.820385      0.107692     0.307692
# Panama                 10.000000      0.070000     0.250000
# Papua New Guinea       10.000000      0.120000     0.000000
# Peru                    9.866000      0.066000     0.100000
# Philippines             9.866000      0.074000     0.000000
# Rwanda                  9.330000      0.110000     0.000000
# Taiwan                  9.964400      0.081067     0.066667
# Tanzania               10.000000      0.119000     0.000000
# Thailand                9.958125      0.090938     0.000000
# Uganda                  9.363333      0.113611     0.138889
# United States           9.643218      0.050920     0.000000
# Vietnam                 9.583750      0.067500     0.000000
# Zambia                 10.000000      0.000000     0.000000
#
#                    AVG_Category.One.Defects  AVG_Category.Two.Defects  Rec_Cnt
# Country.of.Origin
# Brazil                             0.128788                  3.598485      132
# Burundi                            0.000000                  2.500000        2
# China                              0.000000                  4.000000       16
# Colombia                           0.377049                  1.939891      183
# Costa Rica                         0.352941                  2.823529       51
# Cote dIvoire                       1.000000                  2.000000        1
# Ecuador                            0.000000                  0.333333        3
# El Salvador                        0.142857                  3.571429       21
# Ethiopia                           0.250000                  5.159091       44
# Guatemala                          0.187845                  3.419890      181
# Haiti                              1.500000                  3.500000        6
# Honduras                           0.056604                  3.566038       53
# India                              1.428571                  0.357143       14
# Indonesia                          0.300000                  4.200000       20
# Japan                              0.000000                  0.000000        1
# Kenya                              0.040000                  2.520000       25
# Laos                               0.000000                  0.000000        3
# Malawi                             0.000000                  1.363636       11
# Mauritius                          0.000000                  0.000000        1
# Mexico                             0.843220                  6.779661      236
# Myanmar                            0.125000                  5.750000        8
# Nicaragua                          0.269231                  2.769231       26
# Panama                             0.750000                  2.500000        4
# Papua New Guinea                   0.000000                  1.000000        1
# Peru                               1.300000                  3.700000       10
# Philippines                        0.000000                  2.000000        5
# Rwanda                             0.000000                  0.000000        1
# Taiwan                             0.453333                  0.333333       75
# Tanzania                           0.025000                  4.025000       40
# Thailand                           0.062500                  0.500000       32
# Uganda                             0.388889                  3.583333       36
# United States                      1.160920                  3.160920       87
# Vietnam                            9.250000                  3.750000        8
# Zambia                             1.000000                  3.000000        1

# %%
# Cantidad de filas y columnas:
print(f"El número de filas que tenemos es {df.shape[0]}, y el número de columnas es {df.shape[1]}.")
# Out:
# El número de filas que tenemos es 34, y el número de columnas es 14.

# %%
# Function to view the complete Dataframe information.
def get_csv_info(csv):
    # Display the DataFrame info
    print("CSV Information:\n")
    print("-----------------------------------------------------------------------")
    df.info()
    print("-----------------------------------------------------------------------")
    
    # Display the column names
    print("\nColumn Names:")
    print("-----------------------------------------------------------------------")
    print(df.columns)
    print("-----------------------------------------------------------------------")
    
    return 

# Function to view the descriptions of the numerical and categorical columns of the Dataframe.
def describe_dataframe(csv):
    # Describe numerical columns
    print("Numerical Columns Description:\n")
    print("-----------------------------------------------------------------------")
    print(df.describe().T)
    print("-----------------------------------------------------------------------")

    return

# %%
get_csv_info(df)
# Out:
# CSV Information:
#
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, Brazil to Zambia
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   AVG_Aroma                 34 non-null     float64
#  1   AVG_Flavor                34 non-null     float64
#  2   AVG_Aftertaste            34 non-null     float64
#  3   AVG_Acidity               34 non-null     float64
#  4   AVG_Body                  34 non-null     float64
#  5   AVG_Balance               34 non-null     float64
#  6   AVG_Uniformity            34 non-null     float64
#  7   AVG_Clean.Cup             34 non-null     float64
#  8   AVG_Sweetness             34 non-null     float64
#  9   AVG_Moisture              34 non-null     float64
#  10  AVG_Quakers               34 non-null     float64
#  11  AVG_Category.One.Defects  34 non-null     float64
#  12  AVG_Category.Two.Defects  34 non-null     float64
#  13  Rec_Cnt                   34 non-null     int64
# dtypes: float64(13), int64(1)
# memory usage: 4.0+ KB
# -----------------------------------------------------------------------
#
# Column Names:
# -----------------------------------------------------------------------
# Index(['AVG_Aroma', 'AVG_Flavor', 'AVG_Aftertaste', 'AVG_Acidity', 'AVG_Body',
#        'AVG_Balance', 'AVG_Uniformity', 'AVG_Clean.Cup', 'AVG_Sweetness',
#        'AVG_Moisture', 'AVG_Quakers', 'AVG_Category.One.Defects',
#        'AVG_Category.Two.Defects', 'Rec_Cnt'],
#       dtype='object')
# -----------------------------------------------------------------------

# %%
describe_dataframe(df)
# Out:
# Numerical Columns Description:
#
# -----------------------------------------------------------------------
#                           count       mean        std       min       25%  \
# AVG_Aroma                  34.0   7.582751   0.223441  7.153333  7.429396
# AVG_Flavor                 34.0   7.531320   0.270468  6.998333  7.376006
# AVG_Aftertaste             34.0   7.421452   0.237505  6.830000  7.251818
# AVG_Acidity                34.0   7.521099   0.262009  7.000000  7.373437
# AVG_Body                   34.0   7.503383   0.338542  6.026667  7.344470
# AVG_Balance                34.0   7.510356   0.278009  6.970000  7.378864
# AVG_Uniformity             34.0   9.837106   0.208350  9.330000  9.781154
# AVG_Clean.Cup              34.0   9.838450   0.297189  8.555000  9.857418
# AVG_Sweetness              34.0   9.755617   0.476489  7.619286  9.811525
# AVG_Moisture               34.0   0.083914   0.032743  0.000000  0.066375
# AVG_Quakers                34.0   0.114337   0.157436  0.000000  0.000000
# AVG_Category.One.Defects   34.0   0.629198   1.592121  0.000000  0.000000
# AVG_Category.Two.Defects   34.0   2.579528   1.748704  0.000000  1.090909
# Rec_Cnt                    34.0  39.352941  58.833037  1.000000  3.250000
#
#                                 50%        75%         max
# AVG_Aroma                  7.577292   7.673915    8.330000
# AVG_Flavor                 7.532690   7.636406    8.420000
# AVG_Aftertaste             7.432765   7.563155    7.893864
# AVG_Acidity                7.505720   7.647814    8.330000
# AVG_Body                   7.543523   7.659175    8.080000
# AVG_Balance                7.494945   7.671143    8.250000
# AVG_Uniformity             9.918643  10.000000   10.000000
# AVG_Clean.Cup              9.958281  10.000000   10.000000
# AVG_Sweetness              9.951036  10.000000   10.000000
# AVG_Moisture               0.083333   0.110000    0.130000
# AVG_Quakers                0.019068   0.202908    0.500000
# AVG_Category.One.Defects   0.165351   0.675833    9.250000
# AVG_Category.Two.Defects   2.796380   3.594697    6.779661
# Rec_Cnt                   15.000000  43.000000  236.000000
# -----------------------------------------------------------------------
